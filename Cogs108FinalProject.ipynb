# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ARJISPublicCrime112019.txt')

# %%
df
# Out:
#                       CM_LEGEND         agency  \
# 0           MOTOR VEHICLE THEFT  NATIONAL CITY
# 1                      BURGLARY  NATIONAL CITY
# 2                 THEFT/LARCENY  NATIONAL CITY
# 3                       ASSAULT  NATIONAL CITY
# 4                 THEFT/LARCENY  NATIONAL CITY
# 5                 THEFT/LARCENY  NATIONAL CITY
# 6                       ASSAULT  NATIONAL CITY
# 7                 THEFT/LARCENY  NATIONAL CITY
# 8                       ASSAULT  NATIONAL CITY
# 9                       ROBBERY  NATIONAL CITY
# 10                    VANDALISM  NATIONAL CITY
# 11     DRUGS/ALCOHOL VIOLATIONS      SAN DIEGO
# 12     DRUGS/ALCOHOL VIOLATIONS    CHULA VISTA
# 13     DRUGS/ALCOHOL VIOLATIONS    CHULA VISTA
# 14                      WEAPONS    CHULA VISTA
# 15     DRUGS/ALCOHOL VIOLATIONS    CHULA VISTA
# 16                      WEAPONS    CHULA VISTA
# 17     DRUGS/ALCOHOL VIOLATIONS    CHULA VISTA
# 18     DRUGS/ALCOHOL VIOLATIONS    CHULA VISTA
# ...

# %%
df.shape
# Out:
# (63806, 7)

# %%
df['ZipCode'].nunique()
# Out:
# 153

# %%
df = df[df['CM_LEGEND']=='DUI']
df
# Out:
#       CM_LEGEND       agency                Charge_Description_Orig  \
# 27          DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# 41          DUI      SHERIFF                        DUI ALCOHOL (M)
# 68          DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# 86          DUI  CHULA VISTA                        DUI ALCOHOL (M)
# 102         DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# 103         DUI  CHULA VISTA                        DUI ALCOHOL (M)
# 120         DUI      SHERIFF                        DUI ALCOHOL (M)
# 155         DUI  CHULA VISTA                        DUI ALCOHOL (M)
# 156         DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# 157         DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# 171         DUI    SAN DIEGO       DUI ALCOHOL 0.08 PERCENT W/PRIOR
# 178         DUI     CARLSBAD                        DUI ALCOHOL (M)
# 188         DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# ...

# %%
df['ZipCode'].nunique()
# Out:
# 85

# %%
len(df['ZipCode']) - df['ZipCode'].count()
# Out:
# 23

# %%
df = df.dropna(subset=['ZipCode'])

# %%
df['ZipCode'] = df['ZipCode'].astype('int64', copy=False)
df
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       CM_LEGEND       agency                Charge_Description_Orig  \
# 27          DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# 41          DUI      SHERIFF                        DUI ALCOHOL (M)
# 68          DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# 86          DUI  CHULA VISTA                        DUI ALCOHOL (M)
# 102         DUI  CHULA VISTA               DUI ALC/0.08 PERCENT (M)
# 103         DUI  CHULA VISTA                        DUI ALCOHOL (M)
# 120         DUI      SHERIFF                        DUI ALCOHOL (M)
# ...

# %%
len(df) - df.count()
# Out:
# CM_LEGEND                    0
# agency                       0
# Charge_Description_Orig      0
# activityDate                 0
# BLOCK_ADDRESS                0
# ZipCode                      0
# community                  124
# dtype: int64
